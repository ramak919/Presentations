# %%
import pandas as pd

# %% [markdown]
# # Load Sample Data

# %%
titanic_url='https://raw.githubusercontent.com/ramak919/presentations/master/OAUG/2019%20Pandas%20vs%20SQL/Data/Titanic.csv'
tips_url = 'https://raw.githubusercontent.com/ramak919/presentations/master/OAUG/2019%20Pandas%20vs%20SQL/Data/tips.csv'
employee_url='https://github.com/ramak919/presentations/blob/master/OAUG/2019%20Pandas%20vs%20SQL/Data/Oracle%20Employee%20Data.xlsx?raw=true'

import pandas as pd
import numpy as np

# Read from csv 
titanic_df      = pd.read_csv(titanic_url)
tips_df         = pd.read_csv(tips_url)

# Read Excel with multiple sheets
employee_data   = pd.read_excel(employee_url,sheet_name=None)
employee_df     = employee_data['Employee']
dept_df         = employee_data['Department']


#print(employee_data.keys())
#tips = pd.read_csv(tips_url)

# %% [markdown]
# # Descriptive Data Info

# %% [markdown]
# ## Titanic  Descriptive Info

# %%
# Descriptive Info
titanic_df.shape                    # No of Rows, Columns
titanic_df.columns                  # Column  Names
titanic_df.describe()               # Statistic Info
titanic_df.describe(include='all')  # Statistical Info including text columns
titanic_df.memory_usage()           # memory Usage by Column
titanic_df.nunique()                # Unique values for each column
titanic_df.info()                   # Column name , no of values and data type
titanic_df.describe(include='all')  # Statistical Info including text columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
#         PassengerId      Pclass               Name   Sex         Age  \
# count    418.000000  418.000000                418   418  332.000000
# unique          NaN         NaN                418     2         NaN
# top             NaN         NaN  Foley, Mr. Joseph  male         NaN
# freq            NaN         NaN                  1   266         NaN
# mean    1100.500000    2.265550                NaN   NaN   30.272590
# std      120.810458    0.841838                NaN   NaN   14.181209
# min      892.000000    1.000000                NaN   NaN    0.170000
# 25%      996.250000    1.000000                NaN   NaN   21.000000
# 50%     1100.500000    3.000000                NaN   NaN   27.000000
# 75%     1204.750000    3.000000                NaN   NaN   39.000000
# max     1309.000000    3.000000                NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# count   418.000000  418.000000       418  417.000000               91      418
# unique         NaN         NaN       363         NaN               76        3
# top            NaN         NaN  PC 17608         NaN  B57 B59 B63 B66        S
# freq           NaN         NaN         5         NaN                3      270
# mean      0.447368    0.392344       NaN   35.627188              NaN      NaN
# std       0.896760    0.981429       NaN   55.907576              NaN      NaN
# min       0.000000    0.000000       NaN    0.000000              NaN      NaN
# 25%       0.000000    0.000000       NaN    7.895800              NaN      NaN
# 50%       0.000000    0.000000       NaN   14.454200              NaN      NaN
# 75%       1.000000    0.000000       NaN   31.500000              NaN      NaN
# max       8.000000    9.000000       NaN  512.329200              NaN      NaN

# %% [markdown]
# ## Tips Descriptive Info

# %%
titanic_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Descriptive Info
tips_df.shape                    # No of Rows, Columns
tips_df.columns                  # Column  Names
tips_df.describe()               # Statistic Info
tips_df.describe(include='all')  # Statistical Info including text columns
tips_df.memory_usage()           # memory Usage by Column
tips_df.nunique()                # Unique values for each column
tips_df.info()                   # Column name , no of values and data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# ### Tips Descriptive Info Detail

# %%
tips_df.shape                    # No of Rows, Columns
# Out:
# (244, 7)

# %%
tips_df.columns                  # Column  Names
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#tips_df.describe()               # Statistic Info
tips_df.describe(include='all')  # Statistical Info including text columns
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips_df.memory_usage()           # memory Usage by Column
# Out:
# Index           80
# total_bill    1952
# tip           1952
# sex           1952
# smoker        1952
# day           1952
# time          1952
# size          1952
# dtype: int64

# %%
tips_df.nunique()                # Unique values for each column
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
tips_df.info()                   # Column name , no of values and data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %%
tips_df.describe(include='all')  # Statistical Info including text columns
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# # Row Selection

# %% [markdown]
# ## Titanic Where

# %%
titanic_df.head(2)                     # Get first 2 rows
titanic_df.tail(2)                     # Get Last 2 rows
titanic_df.sample(n=5,frac=None)       # 5 random sample of rows
titanic_df.sample(n=None,frac=.6)      # Randomly select 60% of rows
titanic_df.nlargest(5,columns='Fare')  # Get 5 Rows with highest fares for a given column
titanic_df.nsmallest(5,columns='Fare') # Get 5 Rows with lowest fares for a given column
# Out:
#      PassengerId  Pclass                                   Name   Sex   Age  \
# 266         1158       1  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 372         1264       1                Ismay, Mr. Joseph Bruce  male  49.0
# 21           913       3              Olsen, Master. Artur Karl  male   9.0
# 116         1008       3                       Thomas, Mr. John  male   NaN
# 133         1025       3                  Thomas, Mr. Charles P  male   NaN
#
#      SibSp  Parch   Ticket    Fare        Cabin Embarked
# 266      0      0   112051  0.0000          NaN        S
# 372      0      0   112058  0.0000  B52 B54 B56        S
# 21       0      1  C 17368  3.1708          NaN        S
# 116      0      0     2681  6.4375          NaN        C
# 133      1      0     2621  6.4375          NaN        C

# %%
titanic_df[['Sex','Embarked']].drop_duplicates(subset=['Sex','Embarked']) # Select Distinct of columns

titanic_df[titanic_df['Sex']=='male']                  # Select rows where Sex is male
titanic_df[titanic_df['Name'].str.contains("Jame")]    # Like Condition

titanic_df[titanic_df['Cabin'].isin(['D22','D28'])]    # IN Condition
titanic_df[~titanic_df['Cabin'].isin(['D22','D28'])]   # Not in Condition

titanic_df[titanic_df['Cabin'].notnull()]              # Get rows where given column has no null values
titanic_df[titanic_df['Cabin'].isnull()]               # Get rows where given column has null values
titanic_df.isnull().T.any().T.sum()                    # how many rows there are with "one or more NaNs":
titanic_df[titanic_df.isnull().T.any().T]              # Get rows where any of the column val is null
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# 11           903       1                         Jones, Mr. Charles Cresson
# 13           905       2                               Howard, Mr. Benjamin
# 15           907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 16           908       2                                  Keane, Mr. Daniel
# 17           909       3                                  Assaf, Mr. Gerios
# 18           910       3                       Ilmakangas, Miss. Ida Livija
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 20           912       1                             Rothschild, Mr. Martin
# 21           913       3                          Olsen, Master. Artur Karl
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 23           915       1                    Williams, Mr. Richard Norris II
# 25           917       3                            Robins, Mr. Alexander A
# 27           919       3                                  Daher, Mr. Shedid
# 29           921       3                                  Samaan, Mr. Elias
# 30           922       2                       Louch, Mr. Charles Alexander
# 31           923       2                      Jefferys, Mr. Clifford Thomas
# 32           924       3           Dean, Mrs. Bertram (Eva Georgetta Light)
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 35           927       3   Katavelas, Mr. Vassilios (Catavelas Vassilios")"
# ..           ...     ...                                                ...
# 377         1269       2                       Cotterill, Mr. Henry Harry""
# 379         1271       3                        Asplund, Master. Carl Edgar
# 380         1272       3                              O'Connor, Mr. Patrick
# 381         1273       3                                  Foley, Mr. Joseph
# 382         1274       3                         Risien, Mrs. Samuel (Emma)
# 383         1275       3                McNamee, Mrs. Neal (Eileen O'Leary)
# 384         1276       2                     Wheeler, Mr. Edwin Frederick""
# 385         1277       2                                 Herman, Miss. Kate
# 386         1278       3                     Aronsson, Mr. Ernst Axel Algot
# 387         1279       2                                    Ashby, Mr. John
# 388         1280       3                               Canavan, Mr. Patrick
# 389         1281       3                        Palsson, Master. Paul Folke
# 392         1284       3                      Abbott, Master. Eugene Joseph
# 393         1285       2                               Gilbert, Mr. William
# 394         1286       3                           Kink-Heilmann, Mr. Anton
# 396         1288       3                               Colbert, Mr. Patrick
# 398         1290       3                     Larsson-Rondberg, Mr. Edvard A
# 399         1291       3                           Conlon, Mr. Thomas Henry
# 401         1293       2                                    Gale, Mr. Harry
# 402         1294       1                     Gibson, Miss. Dorothy Winifred
# 403         1295       1                             Carrau, Mr. Jose Pedro
# 406         1298       2                          Ware, Mr. William Jeffery
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 409         1301       3                          Peacock, Miss. Treasteall
# 410         1302       3                             Naughton, Miss. Hannah
# 412         1304       3                     Henriksson, Miss. Jenny Lovisa
# 413         1305       3                                 Spector, Mr. Woolf
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 0      male  34.5      0      0              330911   7.8292   NaN        Q
# 1    female  47.0      1      0              363272   7.0000   NaN        S
# 2      male  62.0      0      0              240276   9.6875   NaN        Q
# 3      male  27.0      0      0              315154   8.6625   NaN        S
# 4    female  22.0      1      1             3101298  12.2875   NaN        S
# 5      male  14.0      0      0                7538   9.2250   NaN        S
# 6    female  30.0      0      0              330972   7.6292   NaN        Q
# 7      male  26.0      1      1              248738  29.0000   NaN        S
# 8    female  18.0      0      0                2657   7.2292   NaN        C
# 9      male  21.0      2      0           A/4 48871  24.1500   NaN        S
# 10     male   NaN      0      0              349220   7.8958   NaN        S
# 11     male  46.0      0      0                 694  26.0000   NaN        S
# 13     male  63.0      1      0               24065  26.0000   NaN        S
# 15   female  24.0      1      0       SC/PARIS 2167  27.7208   NaN        C
# 16     male  35.0      0      0              233734  12.3500   NaN        Q
# 17     male  21.0      0      0                2692   7.2250   NaN        C
# 18   female  27.0      1      0    STON/O2. 3101270   7.9250   NaN        S
# 19   female  45.0      0      0                2696   7.2250   NaN        C
# 20     male  55.0      1      0            PC 17603  59.4000   NaN        C
# 21     male   9.0      0      1             C 17368   3.1708   NaN        S
# 22   female   NaN      0      0            PC 17598  31.6833   NaN        S
# 23     male  21.0      0      1            PC 17597  61.3792   NaN        C
# 25     male  50.0      1      0           A/5. 3337  14.5000   NaN        S
# 27     male  22.5      0      0                2698   7.2250   NaN        C
# 29     male   NaN      2      0                2662  21.6792   NaN        C
# 30     male  50.0      1      0          SC/AH 3085  26.0000   NaN        S
# 31     male  24.0      2      0          C.A. 31029  31.5000   NaN        S
# 32   female  33.0      1      2           C.A. 2315  20.5750   NaN        S
# 33   female   NaN      1      2          W./C. 6607  23.4500   NaN        S
# 35     male  18.5      0      0                2682   7.2292   NaN        C
# ..      ...   ...    ...    ...                 ...      ...   ...      ...
# 377    male  21.0      0      0               29107  11.5000   NaN        S
# 379    male   5.0      4      2              347077  31.3875   NaN        S
# 380    male   NaN      0      0              366713   7.7500   NaN        Q
# 381    male  26.0      0      0              330910   7.8792   NaN        Q
# 382  female   NaN      0      0              364498  14.5000   NaN        S
# 383  female  19.0      1      0              376566  16.1000   NaN        S
# 384    male   NaN      0      0       SC/PARIS 2159  12.8750   NaN        S
# 385  female  24.0      1      2              220845  65.0000   NaN        S
# 386    male  24.0      0      0              349911   7.7750   NaN        S
# 387    male  57.0      0      0              244346  13.0000   NaN        S
# 388    male  21.0      0      0              364858   7.7500   NaN        Q
# 389    male   6.0      3      1              349909  21.0750   NaN        S
# 392    male  13.0      0      2           C.A. 2673  20.2500   NaN        S
# 393    male  47.0      0      0          C.A. 30769  10.5000   NaN        S
# 394    male  29.0      3      1              315153  22.0250   NaN        S
# 396    male  24.0      0      0              371109   7.2500   NaN        Q
# 398    male  22.0      0      0              347065   7.7750   NaN        S
# 399    male  31.0      0      0               21332   7.7333   NaN        Q
# 401    male  38.0      1      0               28664  21.0000   NaN        S
# 402  female  22.0      0      1              112378  59.4000   NaN        C
# 403    male  17.0      0      0              113059  47.1000   NaN        S
# 406    male  23.0      1      0               28666  10.5000   NaN        S
# 408  female   NaN      0      0              334915   7.7208   NaN        Q
# 409  female   3.0      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 410  female   NaN      0      0              365237   7.7500   NaN        Q
# 412  female  28.0      0      0              347086   7.7750   NaN        S
# 413    male   NaN      0      0           A.5. 3236   8.0500   NaN        S
# 415    male  38.5      0      0  SOTON/O.Q. 3101262   7.2500   NaN        S
# 416    male   NaN      0      0              359309   8.0500   NaN        S
# 417    male   NaN      1      1                2668  22.3583   NaN        C
#
# [331 rows x 11 columns]

# %% [markdown]
# ## Tips  Where

# %%
tips_df.head(2)                     # Get first 2 rows
tips_df.tail(2)                     # Get Last 2 rows
tips_df.sample(n=5,frac=None)       # 5 random sample of rows
tips_df.sample(n=None,frac=.6)      # Randomly select 60% of rows
tips_df.nlargest(5,columns='total_bill')  # Get 5 Rows with highest fares for a given column
tips_df.nsmallest(5,columns='total_bill') # Get 5 Rows with lowest fares for a given column
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 149        7.51  2.00    Male     No  Thur   Lunch     2

# %%
tips_df[tips_df['time'] == 'Dinner'].head(5)
# tips of more than $5.00 at Dinner meals
tips_df[(tips_df['time'] == 'Dinner') & (tips_df['tip'] > 5.00)]

# tips by parties of at least 5 diners OR bill total was more than $45
tips_df[(tips_df['size'] >= 5) | (tips_df['total_bill'] > 45)]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 125       29.80   4.20  Female     No  Thur   Lunch     6
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 185       20.69   5.00    Male     No   Sun  Dinner     5
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 216       28.15   3.00    Male    Yes   Sat  Dinner     5

# %% [markdown]
# # Joins ( Move Join After Aggregation)

# %%
#dept_df.head()
employee_df.head()
# Out:
#    empno  ename       job     mgr   hiredate   sal   comm  deptno
# 0   7369  SMITH     CLERK  7902.0 1993-06-13   800    0.0      20
# 1   7499  ALLEN  SALESMAN  7698.0 1998-08-15  1600  300.0      30
# 2   7521   WARD  SALESMAN  7698.0 1996-03-26  1250  500.0      30
# 3   7566  JONES   MANAGER  7839.0 1995-10-31  2975    NaN      20
# 4   7698  BLAKE   MANAGER  7839.0 1992-06-11  2850    NaN      30

# %%
employee_dept_df=pd.merge(employee_df
                          ,dept_df
                          ,how         ='outer'         # left,right,outer,inner
                          ,on          ='deptno'
                         , indicator   = True)
print(employee_dept_df.shape)
# Out:
# (15, 11)

# %%
#employee_dept_df.tail()

# %% [markdown]
# # Aggregation ( Group by / Pivot /Cross Tab)

# %% [markdown]
# ## Pivot

# %%
tips_df.pivot_table(  index     = 'day'
                    , columns   = ['time']
                    , values    = ['tip']
                    , aggfunc   = 'mean')
# Out:
#            tip
# time    Dinner     Lunch
# day
# Fri   2.940000  2.382857
# Sat   2.993103       NaN
# Sun   3.255132       NaN
# Thur  3.000000  2.767705

# %%
#aggfunc_name='mean'
#aggfunc_name='sum'
#aggfunc_name='max'
aggfunc_name='min'
tips_df.pivot_table(  index     = 'day'
                    , columns   = ['time','sex']
                    , values    = ['tip','total_bill']
                    , aggfunc   = aggfunc_name)
# Out:
#         tip                    total_bill
# time Dinner        Lunch           Dinner         Lunch
# sex  Female  Male Female  Male     Female   Male Female  Male
# day
# Fri    1.00  1.50   2.00  1.58       5.75  12.03  10.09  8.58
# Sat    1.00  1.00    NaN   NaN       3.07   7.74    NaN   NaN
# Sun    1.01  1.32    NaN   NaN       9.60   7.25    NaN   NaN
# Thur   3.00   NaN   1.25  1.44      18.78    NaN   8.35  7.51

# %%
aggfunc_name={'tip'        : np.mean,
              'total_bill' : [min, max, np.mean]}

tips_df.pivot_table( index      = 'day'
                   #, columns   = ['time']
                   , values     = ['tip','total_bill']
                   , aggfunc    = aggfunc_name)
# Out:
#            tip total_bill
#           mean        max       mean   min
# day
# Fri   2.734737      40.17  17.151579  5.75
# Sat   2.993103      50.81  20.441379  3.07
# Sun   3.255132      48.17  21.410000  7.25
# Thur  2.771452      43.11  17.682742  7.51

# %% [markdown]
# ## Group by

# %% [markdown]
# ### Employee Group by

# %%
#employee_dept_df.groupby(['dname','job'],as_index =False) ['sal'].sum()
employee_group=employee_dept_df.groupby(['dname','job'],as_index =False)
employee_group.groups
# Out:
# {('Accounting', 'CLERK'): Int64Index([13], dtype='int64'),
#  ('Accounting', 'MANAGER'): Int64Index([11], dtype='int64'),
#  ('Accounting', 'PRESIDENT'): Int64Index([12], dtype='int64'),
#  ('Operations', nan): Int64Index([14], dtype='int64'),
#  ('Research', 'ANALYST'): Int64Index([2, 4], dtype='int64'),
#  ('Research', 'CLERK'): Int64Index([0, 3], dtype='int64'),
#  ('Research', 'MANAGER'): Int64Index([1], dtype='int64'),
#  ('Sales', 'CLERK'): Int64Index([9], dtype='int64'),
#  ('Sales', 'MANAGER'): Int64Index([7], dtype='int64'),
#  ('Sales', 'SALESMAN'): Int64Index([5, 6, 8, 10], dtype='int64')}

# %%
len(employee_group.groups)
employee_group.get_group(('Research', 'ANALYST'))   # Get data for
# Out:
#     empno  ename      job     mgr   hiredate     sal  comm  deptno     dname  \
# 2  7788.0  SCOTT  ANALYST  7566.0 1996-03-05  3000.0   NaN      20  Research
# 4  7902.0   FORD  ANALYST  7566.0 1997-12-05  3000.0   NaN      20  Research
#
#   location _merge
# 2   Dallas   both
# 4   Dallas   both

# %%
employee_group['sal'].count()
#employee_group['sal'].sum()
#employee_group.agg()
# Out:
#         dname        job  sal
# 0  Accounting      CLERK    1
# 1  Accounting    MANAGER    1
# 2  Accounting  PRESIDENT    1
# 3    Research    ANALYST    2
# 4    Research      CLERK    2
# 5    Research    MANAGER    1
# 6       Sales      CLERK    1
# 7       Sales    MANAGER    1
# 8       Sales   SALESMAN    4

# %% [markdown]
# ### Tips Group By

# %%
tips_df.groupby('day').agg({  'tip': np.mean
                            , 'day': np.size})
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
tips_df.groupby('day').agg({  'tip': {"Avg Tip":np.mean}
                            , 'day': {"Count"  :np.size}})
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#            tip   day
#        Avg Tip Count
# day
# Fri   2.734737    19
# Sat   2.993103    87
# Sun   3.255132    76
# Thur  2.771452    62

# %%
import numpy as np
tips_df.groupby('sex').size()
tips_df.groupby('sex').count()
tips_df.groupby('sex')['total_bill'].count()
tips_df.groupby('day').agg({'tip': np.mean, 'day': np.size})
tips_df.groupby(['smoker', 'day']).agg({'tip': {"tip_size":np.size, "tip_mean":np.mean}})
#tips.groupby(['smoker', 'day']).agg({'tip': {"tip_size":np.size, "tip_mean":np.mean}}).unstack()
tips_df.groupby('day').agg({'tip': np.mean, 'day': np.size})
tips_df.groupby(['smoker', 'day']).agg({'tip': [np.size, np.mean]})
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#               tip
#              size      mean
# smoker day
# No     Fri    4.0  2.812500
#        Sat   45.0  3.102889
#        Sun   57.0  3.167895
#        Thur  45.0  2.673778
# Yes    Fri   15.0  2.714000
#        Sat   42.0  2.875476
#        Sun   19.0  3.516842
#        Thur  17.0  3.030000

# %%
tips_df.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
tips_df.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %%
tips_df.groupby('sex')['total_bill'].count()
# Out:
# sex
# Female     87
# Male      157
# Name: total_bill, dtype: int64

# %%
tips_df.groupby('day').agg({'tip': np.mean, 'day': np.size})
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
# Filter for rows where group by criteria has less than 5 rows
#(tips.groupby(['smoker', 'day'])[['smoker', 'day','tip']]
# .filter(lambda x: x['tip'].count()<5)
# )

# %% [markdown]
# ### List Agg

# %%
df_listagg=tips_df[['day','time']].drop_duplicates(subset=['day','time'])
df_listagg
# Out:
#       day    time
# 0     Sun  Dinner
# 19    Sat  Dinner
# 77   Thur   Lunch
# 90    Fri  Dinner
# 220   Fri   Lunch
# 243  Thur  Dinner

# %%
(df_listagg
 .groupby(['time'])['day']
 .apply(', '.join)
 .reset_index())
# Out:
#      time                  day
# 0  Dinner  Sun, Sat, Fri, Thur
# 1   Lunch            Thur, Fri

# %% [markdown]
# # Union

# %%
df1 = pd.DataFrame({'city': ['Chicago', 'San Francisco', 'New York City'],
                       'rank': range(1, 4)})
df1
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3

# %%
df2 = pd.DataFrame({'city': ['Chicago', 'Boston', 'Los Angeles'],
                     'rank': [1, 4, 5]})
df2
# Out:
#           city  rank
# 0      Chicago     1
# 1       Boston     4
# 2  Los Angeles     5

# %%
pd.concat([df1, df2])
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 0        Chicago     1
# 1         Boston     4
# 2    Los Angeles     5

# %%
 pd.concat([df1, df2]).drop_duplicates()
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 1         Boston     4
# 2    Los Angeles     5

# %% [markdown]
# # Visualization

# %%
"""‘line’ : line plot (default)
‘bar’ : vertical bar plot
‘barh’ : horizontal bar plot
‘hist’ : histogram
‘box’ : boxplot
‘kde’ : Kernel Density Estimation plot
‘density’ : same as ‘kde’
‘area’ : area plot
‘pie’ : pie plot
‘scatter’ : scatter plot
‘hexbin’ : hexbin plot
"""
#titanic['Pclass'].value_counts().plot()
#employee_dept_df.groupby('dname')['sal'].sum().plot(kind='barh')
# Out:
# '‘line’ : line plot (default)\n‘bar’ : vertical bar plot\n‘barh’ : horizontal bar plot\n‘hist’ : histogram\n‘box’ : boxplot\n‘kde’ : Kernel Density Estimation plot\n‘density’ : same as ‘kde’\n‘area’ : area plot\n‘pie’ : pie plot\n‘scatter’ : scatter plot\n‘hexbin’ : hexbin plot\n'

# %%
#tips

# %%
employee_dept_df.groupby('dname',as_index = False)['sal'].sum()
# Out:
#         dname      sal
# 0  Accounting   8750.0
# 1  Operations      0.0
# 2    Research  10875.0
# 3       Sales   9400.0

# %% [markdown]
# ## Bar Horizantal

# %%
employee_dept_df.groupby('dname')['sal'].sum().plot(kind='barh')

# %% [markdown]
# ## Bar Vertical

# %%
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html
#employee_dept_df.groupby('dname')['sal'].sum().plot('bar')
#employee_dept_df.groupby('job')['sal'].sum().plot('bar')

employee_dept_df.groupby(['job','dname'])['sal'].sum().plot(kind ='bar')

# %% [markdown]
# ## Pie

# %%
employee_dept_df.groupby('job')['sal'].sum().plot(x='job',y='sal',kind='pie')

#employee_dept_df.groupby('dname')['sal'].sum().plot(kind='pie')

# %% [markdown]
# ## Scatter

# %%
tips_df['per']=tips_df['tip']/tips_df['total_bill'] *100
#tips['per']=np.log(tips['per'])
#tips.plot(kind='scatter',x='total_bill', y='tip',)
#tips.plot.scatter(x='total_bill', y='tip')
#tips.plot.scatter(x='total_bill', y='per',c='size',colormap='viridis',figsize =(20,5)  )
#tips.plot.scatter(x='total_bill', y='tip',c='per',colormap='viridis',figsize =(10,10) )
#tips.plot.scatter(x='total_bill', y='tip',c='size',colormap='viridis',figsize =(20,5) ,s=tips['per'] )

tips_df.plot.scatter( x        = 'total_bill'
                     ,y        = 'tip'
                     ,c        = 'per'
                     ,s        = tips_df['per']*6  # Dot Size
                     ,colormap = 'viridis'
                     ,figsize  = (20,5))


#tips.head(2)

# %% [markdown]
# ## Box Plot

# %%
#tips[['size','tip']].plot(kind='box')
#tips[['size','tip']].plot.box()

titanic_df[['Age','Fare']].plot(kind='box')

# %% [markdown]
# ## Heat Map

# %%
#https://blog.algorexhealth.com/2017/09/10-heatmaps-10-python-libraries/
#https://github.com/AlgorexHealth/python-viz-compared/tree/master/data

# %%
flights_url     ='https://raw.githubusercontent.com/AlgorexHealth/python-viz-compared/master/data/flights.csv'
flights_df      = pd.read_csv(flights_url)

flight_matrix   = flights_df.pivot("month", "year", "passengers")

flight_matrix
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# September   136   158   184   209   237   259   312   355   404   404   463
#
# year       1960
# month
# April       461
# August      606
# December    432
# February    391
# January     417
# July        622
# June        535
# March       419
# May         472
# November    390
# October     461
# September   508

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig   = plt.figure(figsize=(12,12))
r     = sns.heatmap(flight_matrix, cmap='BuPu')
r.set_title("Heatmap of Flight Density from 1949 to 1961")
# Out:
# Text(0.5, 1.0, 'Heatmap of Flight Density from 1949 to 1961')

# %% [markdown]
# # Database Conn

# %%
# All of this is basically the same as it would be with Postgres, MySQL, or any other database
# Just pass pandas a connection object and it'll take care of the rest.
from pandas.io import sql
import sqlite3
#conn = sqlite3.connect('data/towed.db')
conn = sqlite3.connect('https://github.com/gjreda/pydata2014nyc/blob/master/data/towed.db?raw=true')

query = "SELECT * FROM towed"
towed = sql.read_sql(query, con=conn, parse_dates={'date':'%m/%d/%Y'})
towed.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-50-25f9789d1ea3> in <module>()
#       2 import sqlite3
#       3 #conn = sqlite3.connect('data/towed.db')
# ----> 4 conn = sqlite3.connect('https://github.com/gjreda/pydata2014nyc/blob/master/data/towed.db?raw=true')
#       5
#       6 query = "SELECT * FROM towed"
#
# OperationalError: unable to open database file
